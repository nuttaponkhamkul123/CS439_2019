# %% [markdown]
# # Questions [40marks]
# * Q1 Who did spend most money for renting?
# * Q2 Which room does make the most amount of income?
# * Q3 How many time Jack Jones rent the room?
# * Q4 What are the roomss rented by Claire Taylor?
# * Q5 what is the total income of ALL rooms in June? Between 1st June 2018(inclusive) and 30th June 2018(inclusive), (use return date).
# * Q6 What are the total incomes of EACH room in June? Between 1st June 2018(inclusive) and 30th June 2018(inclusive), (use return date)
# * Q7 Find members that have total rent time exactly 8 hours in June?
# * Q8 Find members that have total rent time greater than or equal than 9 hours in June?
# * Q9 Find the total rent duration of EACH room in June?
# * Q10 Find the total income of EACH room in June?
#
# # คำถาม [ข้อละ 4 คะแนน รวม 40 คะแนน]
# * Q1 ใครจ่ายเงินค่าเช่ามากที่สุด
# * Q2 ห้องเช่าใดทำรายได้มากที่สุด
# * Q3 Jack Jones เช่าห้องไปกี่ครั้ง
# * Q4 Claire Taylor เช่าห้องไปกี่ครั้ง
# * Q5 ในเดือนมิถุนายนมีรายรับรวมเท่าใด
# * Q6 ในเดือนมิถุนายนแต่ละห้องมีรายรับรวมเท่าใด
# * Q7 หาชื่อสมาชิกที่เช่าห้อง 8 ชั่วโมงในเดือนมิถุนายน
# * Q8 หาชื่อสมาชิกที่เช่าห้องมากกว่าหรือเท่ากับ 9 ชั่วโมงในเดือนมิถุนายน
# * Q9 หาระยะเวลาเช่ารวมของแต่ละห้องในเดือนมิถุนายน
# * Q10 หารายได้รวมของแต่ละห้องในเดือนมิถุนายน

# %%
import pandas as pd

# %%
df_member = pd.read_csv('member.csv')
df_room = pd.read_csv('room.csv')
df_rent = pd.read_csv('rent.csv')
df_member.drop(labels=['Unnamed: 0','mobile'],axis=1,inplace=True)
df_room.drop(labels=['Unnamed: 0','isavailable'],axis=1,inplace=True)
df_rent.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
df_member.head()
# Out:
#    id            name
# 0   1  Oscar Williams
# 1   2     James Jones
# 2   3   Claire Thomas
# 3   4  Oliver Johnson
# 4   5    Oliver Jones

# %%
df_room.head()
# Out:
#    id  number  hour_price
# 0   6     101         105
# 1   7     102         100
# 2   8     103         170
# 3   9     104         130
# 4  10     105         199

# %%
df_rent.head()
# Out:
#     id                       start                        stop  member_id  \
# 0  383  2018-05-09 08:01:18.462109  2018-05-09 09:01:18.462109         48
# 1  384  2018-05-09 08:01:18.462109  2018-05-09 10:01:18.462109          1
# 2  385  2018-05-09 09:01:18.462109  2018-05-09 10:01:18.462109         67
# 3  386  2018-05-09 10:01:18.462109  2018-05-09 12:01:18.462109         18
# 4  387  2018-05-09 12:01:18.462109  2018-05-09 15:01:18.462109         86
#
#    room_id   cost
# 0        7  100.0
# 1        9  260.0
# 2       10  199.0
# 3        7  200.0
# 4        6  315.0

# %%
df_rent.count()
# Out:
# id           3427
# start        3427
# stop         3426
# member_id    3427
# room_id      3427
# cost         3426
# dtype: int64

# %%
df_room.count()
# Out:
# id            5
# number        5
# hour_price    5
# dtype: int64

# %%
df = df_rent\
    .merge(df_member,left_on='member_id',right_on='id')\
    .drop(labels=['id_y'],axis=1)\
    .merge(df_room,left_on='room_id',right_on='id')\
    .drop(labels=['id'],axis=1)
df.head()
# Out:
#    id_x                       start                        stop  member_id  \
# 0   383  2018-05-09 08:01:18.462109  2018-05-09 09:01:18.462109         48
# 1  1839  2018-07-10 12:01:18.462109  2018-07-10 13:01:18.462109         48
# 2  2676  2018-08-16 01:01:18.462109  2018-08-16 02:01:18.462109         48
# 3  3044  2018-08-31 02:01:18.462109  2018-08-31 03:01:18.462109         48
# 4  3105  2018-09-02 13:01:18.462109  2018-09-02 16:01:18.462109         48
#
#    room_id   cost           name  number  hour_price
# 0        7  100.0  Thomas Thomas     102         100
# 1        7  100.0  Thomas Thomas     102         100
# 2        7  100.0  Thomas Thomas     102         100
# 3        7  100.0  Thomas Thomas     102         100
# 4        7  300.0  Thomas Thomas     102         100

# %% [markdown]
# # Q1 ใครจ่ายเงินค่าเช่ามากที่สุด

# %%
df1 = df.groupby(by=['member_id','name'])\
    .agg({'cost' : ['sum']})\
    .sort_values(('cost','sum'),ascending=False)\
    .head(1)
df1
# Out:
#                           cost
#                            sum
# member_id name
# 94        Oscar Smith  15116.0

# %% [markdown]
# # Q2 ห้องเช่าใดทำรายได้มากที่สุด

# %%
df2 = df.groupby(by=['room_id','number'])\
    .agg({'cost' : ['sum']})\
    .sort_values(('cost','sum'),ascending=False)\
    
df2
# Out:
#                     cost
#                      sum
# room_id number
# 10      105     269645.0
# 8       103     235110.0
# 9       104     183560.0
# 6       101     145425.0
# 7       102     140800.0

# %% [markdown]
# # Q3 Jack Jones เช่าห้องไปกี่ครั้ง

# %%
df3 = len(df[df['name'] ==  'Jack Jones'])
df3
# Out:
# 35

# %% [markdown]
# # Q4 Claire Taylor เช่าห้องไปกี่ครั้ง

# %%
df4 = len(df[df['name']== 'Claire Taylor'])
df4
# Out:
# 35

# %% [markdown]
# # Q5 ในเดือนมิถุนายนมีรายรับรวมเท่าใด

# %%
from pytz import datetime
df5 = df.filter(items=['start','stop','cost'],axis=1)
time_start = df5.start
time_stop = df5.stop
# delta_time = time_stop - time_stop

to_date_start = pd.to_datetime(time_start,format='%Y-%m-%d %H:%M:%S')
to_date_stop = pd.to_datetime(time_stop,format='%Y-%m-%d %H:%M:%S')

# %%
# df5['delta'] = to_date_stop - to_date_start
df5['new_date_start'] = to_date_start
df5['new_date_stop'] = to_date_stop
df5['start_month'] = df5.new_date_start.apply(lambda x : x.month)
df5['stop_month'] = df5.new_date_stop.apply(lambda z : z.month)


list = df5[df5['stop_month'] == 6]
list.cost.sum()
# list2.cost.sum()
# list
# Out:
# 196236.0

# %% [markdown]
# # Q6 ในเดือนมิถุนายนแต่ละห้องมีรายรับรวมเท่าใด

# %%
df6 = df_room.merge(df_rent,left_on='id',right_on='room_id')\
    .drop(columns = 'id_x')
df6['stop'] = pd.to_datetime(df6['stop'],format='%Y-%m-%d %H:%M:%S')
df6_new = df6[df6['stop'].dt.month == 6]
df6_new.groupby('room_id').agg({'cost':'sum'})
# Out:
#             cost
# room_id
# 6        30135.0
# 7        30400.0
# 8        48450.0
# 9        37700.0
# 10       49551.0

# %% [markdown]
# # Q7 หาชื่อสมาชิกที่เช่าห้อง 8 ชั่วโมงในเดือนมิถุนายน

# %%
from datetime import datetime, timedelta
init = datetime.strptime( "2018-06-01T00:00:00", "%Y-%m-%dT%H:%M:%S" )
final = datetime.strptime( "2018-06-30T23:59:59", "%Y-%m-%dT%H:%M:%S" )
df7 = df

df7.stop = pd.to_datetime(df7['stop'],format='%Y-%m-%d %H:%M:%S')
df7.start = pd.to_datetime(df7['start'],format='%Y-%m-%d %H:%M:%S')
df7=df[(init<=df.stop) & (df.stop<=final)]

df7['hours'] = df7.stop-df7.start
df7 = df7.groupby('name').agg({'hours':'sum'})
df8 = df7
df7.loc[df7.hours=='08:00:00']




# df7
# Out:
# C:\Users\asus\AppData\Local\Continuum\miniconda3\envs\env\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                   hours
# name
# James Jones    08:00:00
# Oscar Johnson  08:00:00
# William Thomas 08:00:00

# %% [markdown]
# # Q8 หาชื่อสมาชิกที่เช่าห้องมากกว่าหรือเท่ากับ 9 ชั่วโมงในเดือนมิถุนายน

# %%
df8.loc[df8.hours>='09:00:00']
# Out:
#                           hours
# name
# Charlie Brown   1 days 03:00:00
# Charlie Evans   0 days 12:00:00
# Charlie Johnson 0 days 09:00:00
# Charlie Thomas  0 days 22:00:00
# Charlie Wilson  0 days 11:00:00
# Claire Brown    0 days 19:00:00
# Claire Davies   1 days 01:00:00
# Claire Evans    1 days 09:00:00
# Claire Johnson  0 days 09:00:00
# Claire Jones    0 days 10:00:00
# Claire Taylor   0 days 15:00:00
# Claire Thomas   0 days 18:00:00
# Claire Williams 0 days 09:00:00
# Claire Wilson   0 days 16:00:00
# George Davies   0 days 09:00:00
# George Evans    0 days 19:00:00
# George Jones    0 days 15:00:00
# George Smith    1 days 05:00:00
# George Taylor   0 days 18:00:00
# George Williams 0 days 16:00:00
# George Wilson   0 days 17:00:00
# Harry Brown     0 days 10:00:00
# Harry Evans     0 days 19:00:00
# Harry Johnson   0 days 12:00:00
# Harry Jones     0 days 21:00:00
# Harry Smith     0 days 11:00:00
# Harry Thomas    0 days 20:00:00
# Harry Wilson    0 days 15:00:00
# Jack Brown      0 days 09:00:00
# Jack Davies     0 days 22:00:00
# ...                         ...
# Oliver Davies   1 days 00:00:00
# Oliver Evans    0 days 17:00:00
# Oliver Johnson  0 days 13:00:00
# Oliver Jones    0 days 23:00:00
# Oliver Smith    0 days 15:00:00
# Oliver Thomas   0 days 09:00:00
# Oliver Williams 1 days 02:00:00
# 3425  3436 2018-09-15 14:01:18.462109 2018-09-15 16:01:18.462109         25
# 3426  3788 2018-09-30 17:01:18.462109 2018-09-30 19:01:18.462109         25
#
#       room_id   cost            name  number  hour_price
# 0           7  100.0   Thomas Thomas     102         100
# 1           7  100.0   Thomas Thomas     102         100
# 2           7  100.0   Thomas Thomas     102         100
# 3           7  100.0   Thomas Thomas     102         100
# 4           7  300.0   Thomas Thomas     102         100
# 5           7  200.0   Thomas Thomas     102         100
# 6           7  100.0  Oscar Williams     102         100
# 7           7  100.0  Oscar Williams     102         100
# 8           7  300.0  Oscar Williams     102         100
# 9           7  400.0  Oscar Williams     102         100
# 10          7  300.0  Oscar Williams     102         100
# 11          7  200.0  Oscar Williams     102         100
# 12          7  200.0  Oscar Williams     102         100
# 13          7  400.0    Oliver Brown     102         100
# 14          7  200.0    Oliver Brown     102         100
# 15          7  200.0    Oliver Brown     102         100
# 16          7  100.0    Oliver Brown     102         100
# 17          7  300.0    Oliver Brown     102         100
# 18          7  100.0    Oliver Brown     102         100
# 19          7  200.0    Oliver Brown     102         100
# 20          7  200.0    Harry Davies     102         100
# 21          7  200.0    Harry Davies     102         100
# 22          7  100.0    Harry Davies     102         100
# 23          7  300.0    Harry Davies     102         100
# 24          7  300.0    Harry Davies     102         100
# 25          7  300.0    Harry Davies     102         100
# 26          7  200.0    Harry Davies     102         100
# 27          7  100.0    Harry Davies     102         100
# 28          7  200.0    Jacob Taylor     102         100
# 29          7  100.0    Jacob Taylor     102         100
# ...       ...    ...             ...     ...         ...
# 3397        9  130.0    George Smith     104         130
# 3398        9  260.0    George Smith     104         130
# 3399        9  260.0    George Smith     104         130
# 3400        9  130.0    George Smith     104         130
# 3401        9  130.0    George Smith     104         130
# 3402        9  260.0    George Smith     104         130
# 3403        9  390.0    George Smith     104         130
# 3404        9  260.0   James Johnson     104         130
# 3405        9  780.0   James Johnson     104         130
# 3406        9  130.0   James Johnson     104         130
# 3407        9  130.0    Thomas Brown     104         130
# 3408        9  390.0    Thomas Brown     104         130
# 3409        9  130.0    Thomas Brown     104         130
# 3410        9  260.0    Thomas Brown     104         130
# 3411        9  390.0    Thomas Brown     104         130
# 3412        9  520.0    Thomas Brown     104         130
# 3413        9  130.0    Thomas Brown     104         130
# 3414        9  130.0      Jack Smith     104         130
# 3415        9  520.0      Jack Smith     104         130
# 3416        9  130.0      Jack Smith     104         130
# 3417        9  130.0    James Taylor     104         130
# 3418        9  130.0    James Taylor     104         130
# 3419        9  390.0    James Taylor     104         130
# 3420        9  130.0    James Taylor     104         130
# 3421        9  130.0    James Taylor     104         130
# 3422        9  260.0    James Taylor     104         130
# 3423        9  130.0    James Taylor     104         130
# 3424        9  260.0    James Taylor     104         130
# 3425        9  260.0    James Taylor     104         130
# 3426        9  260.0    James Taylor     104         130
#
# [3427 rows x 9 columns]
